# %%
from keras.models import load_model

model = load_model('../../models/rmtpp_baseline.model')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-2c6fedef1f70> in <module>()
#       1 from keras.models import load_model
#       2
# ----> 3 model = load_model('../../models/rmtpp_baseline.model')
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py in load_model(filepath, custom_objects, compile)
#     258             raise ValueError('No model found in config file.')
#     259         model_config = json.loads(model_config.decode('utf-8'))
# ...
